# %%
# !pip install --pre pycaret
# Out:
# Requirement already satisfied: pycaret in d:\py_ana\lib\site-packages (3.0.0rc4)
# Requirement already satisfied: pandas<1.5.0,>=1.3.0 in d:\py_ana\lib\site-packages (from pycaret) (1.4.4)
# Requirement already satisfied: scikit-learn>=1.0 in d:\py_ana\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: plotly>=5.0.0 in d:\py_ana\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: scikit-plot>=0.3.7 in d:\py_ana\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: numpy<1.23,>=1.21 in d:\py_ana\lib\site-packages (from pycaret) (1.21.5)
# Requirement already satisfied: sktime~=0.13.2 in d:\py_ana\lib\site-packages (from pycaret) (0.13.4)
# Requirement already satisfied: category-encoders>=2.4.0 in d:\py_ana\lib\site-packages (from pycaret) (2.5.1.post0)
# Requirement already satisfied: pyod>=0.9.8 in d:\py_ana\lib\site-packages (from pycaret) (1.0.6)
# Requirement already satisfied: plotly-resampler>=0.7.2.2 in d:\py_ana\lib\site-packages (from pycaret) (0.8.3)
# Requirement already satisfied: statsmodels>=0.12.1 in d:\py_ana\lib\site-packages (from pycaret) (0.13.2)
# Requirement already satisfied: markupsafe>=2.0.1 in d:\py_ana\lib\site-packages (from pycaret) (2.0.1)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in d:\py_ana\lib\site-packages (from pycaret) (0.9.1)
# Requirement already satisfied: ipython>=5.5.0 in d:\py_ana\lib\site-packages (from pycaret) (7.31.1)
# Requirement already satisfied: kaleido>=0.2.1 in d:\py_ana\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: pmdarima!=1.8.1,<2.0.0,>=1.8.0 in d:\py_ana\lib\site-packages (from pycaret) (1.8.5)
# Requirement already satisfied: jinja2>=1.2 in d:\py_ana\lib\site-packages (from pycaret) (2.11.3)
# Requirement already satisfied: scipy<1.9.0 in d:\py_ana\lib\site-packages (from pycaret) (1.8.1)
# Requirement already satisfied: tqdm>=4.62.0 in d:\py_ana\lib\site-packages (from pycaret) (4.64.1)
# Requirement already satisfied: requests>=2.27.1 in d:\py_ana\lib\site-packages (from pycaret) (2.28.1)
# Requirement already satisfied: numba~=0.55.0 in d:\py_ana\lib\site-packages (from pycaret) (0.55.1)
# Requirement already satisfied: tbats>=1.1.0 in d:\py_ana\lib\site-packages (from pycaret) (1.1.1)
# Requirement already satisfied: ipywidgets>=7.6.5 in d:\py_ana\lib\site-packages (from pycaret) (7.6.5)
# Requirement already satisfied: schemdraw>=0.14 in d:\py_ana\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: yellowbrick>=1.4 in d:\py_ana\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: joblib>=1.1.0 in d:\py_ana\lib\site-packages (from pycaret) (1.2.0)
# Requirement already satisfied: importlib-metadata>=4.12.0 in d:\py_ana\lib\site-packages (from pycaret) (5.1.0)
# Requirement already satisfied: matplotlib>=3.3.0 in d:\py_ana\lib\site-packages (from pycaret) (3.5.2)
# Requirement already satisfied: lightgbm>=3.0.0 in d:\py_ana\lib\site-packages (from pycaret) (3.3.3)
# Requirement already satisfied: psutil>=5.9.0 in d:\py_ana\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: patsy>=0.5.1 in d:\py_ana\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\py_ana\lib\site-packages (from imbalanced-learn>=0.8.1->pycaret) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in d:\py_ana\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.8.0)
# Requirement already satisfied: matplotlib-inline in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: traitlets>=4.2 in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: backcall in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (63.4.1)
# Requirement already satisfied: decorator in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: pickleshare in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: pygments in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (2.11.2)
# Requirement already satisfied: colorama in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.5)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in d:\py_ana\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in d:\py_ana\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (5.5.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in d:\py_ana\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in d:\py_ana\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.5.2)
# Requirement already satisfied: ipykernel>=4.5.1 in d:\py_ana\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (6.15.2)
# Requirement already satisfied: wheel in d:\py_ana\lib\site-packages (from lightgbm>=3.0.0->pycaret) (0.37.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\py_ana\lib\site-packages (from matplotlib>=3.3.0->pycaret) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in d:\py_ana\lib\site-packages (from matplotlib>=3.3.0->pycaret) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in d:\py_ana\lib\site-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\py_ana\lib\site-packages (from matplotlib>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\py_ana\lib\site-packages (from matplotlib>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in d:\py_ana\lib\site-packages (from matplotlib>=3.3.0->pycaret) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in d:\py_ana\lib\site-packages (from matplotlib>=3.3.0->pycaret) (21.3)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in d:\py_ana\lib\site-packages (from numba~=0.55.0->pycaret) (0.38.0)
# Requirement already satisfied: pytz>=2020.1 in d:\py_ana\lib\site-packages (from pandas<1.5.0,>=1.3.0->pycaret) (2022.1)
# Requirement already satisfied: tenacity>=6.2.0 in d:\py_ana\lib\site-packages (from plotly>=5.0.0->pycaret) (8.0.1)
# Requirement already satisfied: Flask-Cors<4.0.0,>=3.0.10 in d:\py_ana\lib\site-packages (from plotly-resampler>=0.7.2.2->pycaret) (3.0.10)
# Requirement already satisfied: dash<3.0.0,>=2.2.0 in d:\py_ana\lib\site-packages (from plotly-resampler>=0.7.2.2->pycaret) (2.7.0)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in d:\py_ana\lib\site-packages (from plotly-resampler>=0.7.2.2->pycaret) (3.8.3)
# Requirement already satisfied: Werkzeug<=2.1.2 in d:\py_ana\lib\site-packages (from plotly-resampler>=0.7.2.2->pycaret) (2.0.3)
# Requirement already satisfied: jupyter-dash>=0.4.2 in d:\py_ana\lib\site-packages (from plotly-resampler>=0.7.2.2->pycaret) (0.4.2)
# Requirement already satisfied: trace-updater>=0.0.8 in d:\py_ana\lib\site-packages (from plotly-resampler>=0.7.2.2->pycaret) (0.0.9)
# Requirement already satisfied: urllib3 in d:\py_ana\lib\site-packages (from pmdarima!=1.8.1,<2.0.0,>=1.8.0->pycaret) (1.26.11)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in d:\py_ana\lib\site-packages (from pmdarima!=1.8.1,<2.0.0,>=1.8.0->pycaret) (0.29.32)
# Requirement already satisfied: six in d:\py_ana\lib\site-packages (from pyod>=0.9.8->pycaret) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\py_ana\lib\site-packages (from requests>=2.27.1->pycaret) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\py_ana\lib\site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\py_ana\lib\site-packages (from requests>=2.27.1->pycaret) (2022.9.14)
# Requirement already satisfied: deprecated>=1.2.13 in d:\py_ana\lib\site-packages (from sktime~=0.13.2->pycaret) (1.2.13)
# Requirement already satisfied: dash-table==5.0.0 in d:\py_ana\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (5.0.0)
# Requirement already satisfied: Flask>=1.0.4 in d:\py_ana\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (1.1.2)
# Requirement already satisfied: dash-html-components==2.0.0 in d:\py_ana\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in d:\py_ana\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (2.0.0)
# Requirement already satisfied: wrapt<2,>=1.10 in d:\py_ana\lib\site-packages (from deprecated>=1.2.13->sktime~=0.13.2->pycaret) (1.14.1)
# Requirement already satisfied: nest-asyncio in d:\py_ana\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.5)
# Requirement already satisfied: debugpy>=1.0 in d:\py_ana\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.1)
# Requirement already satisfied: tornado>=6.1 in d:\py_ana\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\py_ana\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (7.3.4)
# Requirement already satisfied: pyzmq>=17 in d:\py_ana\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (23.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\py_ana\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: ansi2html in d:\py_ana\lib\site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.7.2.2->pycaret) (1.8.0)
# Requirement already satisfied: retrying in d:\py_ana\lib\site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.7.2.2->pycaret) (1.3.4)
# Requirement already satisfied: jsonschema>=2.6 in d:\py_ana\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (4.16.0)
# Requirement already satisfied: fastjsonschema in d:\py_ana\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (2.16.2)
# Requirement already satisfied: jupyter_core in d:\py_ana\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (4.11.1)
# Requirement already satisfied: wcwidth in d:\py_ana\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in d:\py_ana\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.12)
# Requirement already satisfied: click>=5.1 in d:\py_ana\lib\site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (8.0.4)
# Requirement already satisfied: itsdangerous>=0.24 in d:\py_ana\lib\site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (2.0.1)
# Requirement already satisfied: attrs>=17.4.0 in d:\py_ana\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\py_ana\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (0.18.0)
# Requirement already satisfied: entrypoints in d:\py_ana\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.4)
# Requirement already satisfied: pywin32>=1.0 in d:\py_ana\lib\site-packages (from jupyter_core->nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (302)
# Requirement already satisfied: Send2Trash>=1.8.0 in d:\py_ana\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: nbconvert>=5 in d:\py_ana\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.4)
# Requirement already satisfied: argon2-cffi in d:\py_ana\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.3.0)
# Requirement already satisfied: prometheus-client in d:\py_ana\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.14.1)
# Requirement already satisfied: terminado>=0.8.3 in d:\py_ana\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.13.1)
# Requirement already satisfied: testpath in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.6.0)
# Requirement already satisfied: bleach in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.1.0)
# Requirement already satisfied: jupyterlab-pygments in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: beautifulsoup4 in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.11.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.13)
# Requirement already satisfied: defusedxml in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: pywinpty>=1.1.0 in d:\py_ana\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in d:\py_ana\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in d:\py_ana\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in d:\py_ana\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.3.1)
# Requirement already satisfied: webencodings in d:\py_ana\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: pycparser in d:\py_ana\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.21)

# %%
# !pip install -U --pre pycaret
# Out:
# Requirement already satisfied: pycaret in d:\py_ana\lib\site-packages (3.0.0rc4)
# Requirement already satisfied: plotly-resampler>=0.7.2.2 in d:\py_ana\lib\site-packages (from pycaret) (0.8.3)
# Requirement already satisfied: tbats>=1.1.0 in d:\py_ana\lib\site-packages (from pycaret) (1.1.1)
# Requirement already satisfied: numba~=0.55.0 in d:\py_ana\lib\site-packages (from pycaret) (0.55.1)
# Requirement already satisfied: schemdraw>=0.14 in d:\py_ana\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: pmdarima!=1.8.1,<2.0.0,>=1.8.0 in d:\py_ana\lib\site-packages (from pycaret) (1.8.5)
# Requirement already satisfied: pyod>=0.9.8 in d:\py_ana\lib\site-packages (from pycaret) (1.0.6)
# Requirement already satisfied: markupsafe>=2.0.1 in d:\py_ana\lib\site-packages (from pycaret) (2.0.1)
# Requirement already satisfied: joblib>=1.1.0 in d:\py_ana\lib\site-packages (from pycaret) (1.2.0)
# Requirement already satisfied: kaleido>=0.2.1 in d:\py_ana\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: ipywidgets>=7.6.5 in d:\py_ana\lib\site-packages (from pycaret) (7.6.5)
# Requirement already satisfied: requests>=2.27.1 in d:\py_ana\lib\site-packages (from pycaret) (2.28.1)
# Requirement already satisfied: scikit-learn>=1.0 in d:\py_ana\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: scipy<1.9.0 in d:\py_ana\lib\site-packages (from pycaret) (1.8.1)
# Requirement already satisfied: lightgbm>=3.0.0 in d:\py_ana\lib\site-packages (from pycaret) (3.3.3)
# Requirement already satisfied: jinja2>=1.2 in d:\py_ana\lib\site-packages (from pycaret) (2.11.3)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in d:\py_ana\lib\site-packages (from pycaret) (0.9.1)
# Requirement already satisfied: numpy<1.23,>=1.21 in d:\py_ana\lib\site-packages (from pycaret) (1.21.5)
# Requirement already satisfied: psutil>=5.9.0 in d:\py_ana\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: sktime~=0.13.2 in d:\py_ana\lib\site-packages (from pycaret) (0.13.4)
# Requirement already satisfied: plotly>=5.0.0 in d:\py_ana\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: pandas<1.5.0,>=1.3.0 in d:\py_ana\lib\site-packages (from pycaret) (1.4.4)
# Requirement already satisfied: yellowbrick>=1.4 in d:\py_ana\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: category-encoders>=2.4.0 in d:\py_ana\lib\site-packages (from pycaret) (2.5.1.post0)
# Requirement already satisfied: scikit-plot>=0.3.7 in d:\py_ana\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: importlib-metadata>=4.12.0 in d:\py_ana\lib\site-packages (from pycaret) (5.1.0)
# Requirement already satisfied: ipython>=5.5.0 in d:\py_ana\lib\site-packages (from pycaret) (7.31.1)
# Requirement already satisfied: tqdm>=4.62.0 in d:\py_ana\lib\site-packages (from pycaret) (4.64.1)
# Requirement already satisfied: statsmodels>=0.12.1 in d:\py_ana\lib\site-packages (from pycaret) (0.13.2)
# Requirement already satisfied: matplotlib>=3.3.0 in d:\py_ana\lib\site-packages (from pycaret) (3.5.2)
# Requirement already satisfied: patsy>=0.5.1 in d:\py_ana\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\py_ana\lib\site-packages (from imbalanced-learn>=0.8.1->pycaret) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in d:\py_ana\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.20)
# Requirement already satisfied: backcall in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: pygments in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (2.11.2)
# Requirement already satisfied: matplotlib-inline in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: setuptools>=18.5 in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (63.4.1)
# Requirement already satisfied: decorator in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: pickleshare in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: colorama in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in d:\py_ana\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in d:\py_ana\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in d:\py_ana\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.5.2)
# Requirement already satisfied: ipykernel>=4.5.1 in d:\py_ana\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (6.15.2)
# Requirement already satisfied: nbformat>=4.2.0 in d:\py_ana\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (5.5.0)
# Requirement already satisfied: wheel in d:\py_ana\lib\site-packages (from lightgbm>=3.0.0->pycaret) (0.37.1)
# Requirement already satisfied: cycler>=0.10 in d:\py_ana\lib\site-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\py_ana\lib\site-packages (from matplotlib>=3.3.0->pycaret) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\py_ana\lib\site-packages (from matplotlib>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\py_ana\lib\site-packages (from matplotlib>=3.3.0->pycaret) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in d:\py_ana\lib\site-packages (from matplotlib>=3.3.0->pycaret) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\py_ana\lib\site-packages (from matplotlib>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in d:\py_ana\lib\site-packages (from matplotlib>=3.3.0->pycaret) (4.25.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in d:\py_ana\lib\site-packages (from numba~=0.55.0->pycaret) (0.38.0)
# Requirement already satisfied: pytz>=2020.1 in d:\py_ana\lib\site-packages (from pandas<1.5.0,>=1.3.0->pycaret) (2022.1)
# Requirement already satisfied: tenacity>=6.2.0 in d:\py_ana\lib\site-packages (from plotly>=5.0.0->pycaret) (8.0.1)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in d:\py_ana\lib\site-packages (from plotly-resampler>=0.7.2.2->pycaret) (3.8.3)
# Requirement already satisfied: trace-updater>=0.0.8 in d:\py_ana\lib\site-packages (from plotly-resampler>=0.7.2.2->pycaret) (0.0.9)
# Requirement already satisfied: Werkzeug<=2.1.2 in d:\py_ana\lib\site-packages (from plotly-resampler>=0.7.2.2->pycaret) (2.0.3)
# Requirement already satisfied: jupyter-dash>=0.4.2 in d:\py_ana\lib\site-packages (from plotly-resampler>=0.7.2.2->pycaret) (0.4.2)
# Requirement already satisfied: Flask-Cors<4.0.0,>=3.0.10 in d:\py_ana\lib\site-packages (from plotly-resampler>=0.7.2.2->pycaret) (3.0.10)
# Requirement already satisfied: dash<3.0.0,>=2.2.0 in d:\py_ana\lib\site-packages (from plotly-resampler>=0.7.2.2->pycaret) (2.7.0)
# Requirement already satisfied: urllib3 in d:\py_ana\lib\site-packages (from pmdarima!=1.8.1,<2.0.0,>=1.8.0->pycaret) (1.26.11)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in d:\py_ana\lib\site-packages (from pmdarima!=1.8.1,<2.0.0,>=1.8.0->pycaret) (0.29.32)
# Requirement already satisfied: six in d:\py_ana\lib\site-packages (from pyod>=0.9.8->pycaret) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\py_ana\lib\site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\py_ana\lib\site-packages (from requests>=2.27.1->pycaret) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\py_ana\lib\site-packages (from requests>=2.27.1->pycaret) (2022.9.14)
# Requirement already satisfied: deprecated>=1.2.13 in d:\py_ana\lib\site-packages (from sktime~=0.13.2->pycaret) (1.2.13)
# Requirement already satisfied: dash-table==5.0.0 in d:\py_ana\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (5.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in d:\py_ana\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in d:\py_ana\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (2.0.0)
# Requirement already satisfied: Flask>=1.0.4 in d:\py_ana\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (1.1.2)
# Requirement already satisfied: wrapt<2,>=1.10 in d:\py_ana\lib\site-packages (from deprecated>=1.2.13->sktime~=0.13.2->pycaret) (1.14.1)
# Requirement already satisfied: nest-asyncio in d:\py_ana\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.5)
# Requirement already satisfied: pyzmq>=17 in d:\py_ana\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (23.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\py_ana\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (7.3.4)
# Requirement already satisfied: debugpy>=1.0 in d:\py_ana\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.1)
# Requirement already satisfied: tornado>=6.1 in d:\py_ana\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\py_ana\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: ansi2html in d:\py_ana\lib\site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.7.2.2->pycaret) (1.8.0)
# Requirement already satisfied: retrying in d:\py_ana\lib\site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.7.2.2->pycaret) (1.3.4)
# Requirement already satisfied: jsonschema>=2.6 in d:\py_ana\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (4.16.0)
# Requirement already satisfied: fastjsonschema in d:\py_ana\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (2.16.2)
# Requirement already satisfied: jupyter_core in d:\py_ana\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (4.11.1)
# Requirement already satisfied: wcwidth in d:\py_ana\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in d:\py_ana\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.12)
# Requirement already satisfied: click>=5.1 in d:\py_ana\lib\site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (8.0.4)
# Requirement already satisfied: itsdangerous>=0.24 in d:\py_ana\lib\site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (2.0.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\py_ana\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in d:\py_ana\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (21.4.0)
# Requirement already satisfied: entrypoints in d:\py_ana\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.4)
# Requirement already satisfied: pywin32>=1.0 in d:\py_ana\lib\site-packages (from jupyter_core->nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (302)
# Requirement already satisfied: Send2Trash>=1.8.0 in d:\py_ana\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: nbconvert>=5 in d:\py_ana\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.4)
# Requirement already satisfied: terminado>=0.8.3 in d:\py_ana\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.13.1)
# Requirement already satisfied: prometheus-client in d:\py_ana\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.14.1)
# Requirement already satisfied: argon2-cffi in d:\py_ana\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.3.0)
# Requirement already satisfied: bleach in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.13)
# Requirement already satisfied: defusedxml in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.11.1)
# Requirement already satisfied: testpath in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: pywinpty>=1.1.0 in d:\py_ana\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in d:\py_ana\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in d:\py_ana\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in d:\py_ana\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.3.1)
# Requirement already satisfied: webencodings in d:\py_ana\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: pycparser in d:\py_ana\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.21)

# %%
# !pip install keras-datasets
# !pip install tensorflow_datasets
# !pip install tensorflow --user
# !pip install --upgrade tensorflow
# !pip install tensorflow
# Out:
# Collecting keras-datasets
#   Using cached keras_datasets-0.1.0-py3-none-any.whl (4.2 kB)
# Installing collected packages: keras-datasets
# Successfully installed keras-datasets-0.1.0
# Collecting tensorflow_datasets
#   Downloading tensorflow_datasets-4.7.0-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.4 MB/s eta 0:00:00
# Collecting promise
#   Using cached promise-2.3.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: toml in d:\py_ana\lib\site-packages (from tensorflow_datasets) (0.10.2)
# Collecting absl-py
#   Downloading absl_py-1.3.0-py3-none-any.whl (124 kB)
#      -------------------------------------- 124.6/124.6 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in d:\py_ana\lib\site-packages (from tensorflow_datasets) (2.28.1)
# Requirement already satisfied: protobuf>=3.12.2 in d:\py_ana\lib\site-packages (from tensorflow_datasets) (3.20.3)
# Collecting termcolor
#   Downloading termcolor-2.1.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: six in d:\py_ana\lib\site-packages (from tensorflow_datasets) (1.16.0)
# Collecting tensorflow-metadata
#   Downloading tensorflow_metadata-1.12.0-py3-none-any.whl (52 kB)
#      --------------------------------------- 52.3/52.3 kB 30.3 kB/s eta 0:00:00
# Requirement already satisfied: numpy in d:\py_ana\lib\site-packages (from tensorflow_datasets) (1.21.5)
# Collecting etils[epath]
#   Downloading etils-0.9.0-py3-none-any.whl (140 kB)
#      -------------------------------------- 140.1/140.1 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: dill in d:\py_ana\lib\site-packages (from tensorflow_datasets) (0.3.4)
# Requirement already satisfied: tqdm in d:\py_ana\lib\site-packages (from tensorflow_datasets) (4.64.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\py_ana\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\py_ana\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in d:\py_ana\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\py_ana\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (2022.9.14)
# Collecting importlib_resources
#   Downloading importlib_resources-5.10.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: typing_extensions in d:\py_ana\lib\site-packages (from etils[epath]->tensorflow_datasets) (4.3.0)
# Requirement already satisfied: zipp in d:\py_ana\lib\site-packages (from etils[epath]->tensorflow_datasets) (3.8.0)
# Collecting googleapis-common-protos<2,>=1.52.0
#   Downloading googleapis_common_protos-1.57.0-py2.py3-none-any.whl (217 kB)
#      ------------------------------------ 218.0/218.0 kB 884.1 kB/s eta 0:00:00
# Requirement already satisfied: colorama in d:\py_ana\lib\site-packages (from tqdm->tensorflow_datasets) (0.4.5)
# Building wheels for collected packages: promise
#   Building wheel for promise (setup.py): started
#   Building wheel for promise (setup.py): finished with status 'done'
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21486 sha256=f98d3fcf52f1e5ed0c515afc4696e86c76c73f8a05368dd83b8b3fc7a51430c3
#   Stored in directory: c:\users\`\appdata\local\pip\cache\wheels\e1\e8\83\ddea66100678d139b14bc87692ece57c6a2a937956d2532608
# Successfully built promise
# Installing collected packages: termcolor, promise, importlib_resources, googleapis-common-protos, etils, absl-py, tensorflow-metadata, tensorflow_datasets
# Successfully installed absl-py-1.3.0 etils-0.9.0 googleapis-common-protos-1.57.0 importlib_resources-5.10.1 promise-2.3 tensorflow-metadata-1.12.0 tensorflow_datasets-4.7.0 termcolor-2.1.1
# Collecting pycaret
#   Downloading pycaret-3.0.0rc4-py3-none-any.whl (487 kB)
#      -------------------------------------- 487.2/487.2 kB 1.0 MB/s eta 0:00:00
# Collecting importlib-metadata>=4.12.0
#   Downloading importlib_metadata-5.1.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: numpy<1.23,>=1.21 in d:\py_ana\lib\site-packages (from pycaret) (1.21.5)
# Collecting scipy<1.9.0
#   Using cached scipy-1.8.1-cp39-cp39-win_amd64.whl (36.9 MB)
# Requirement already satisfied: ipywidgets>=7.6.5 in d:\py_ana\lib\site-packages (from pycaret) (7.6.5)
# Requirement already satisfied: markupsafe>=2.0.1 in d:\py_ana\lib\site-packages (from pycaret) (2.0.1)
# Collecting tbats>=1.1.0
#   Downloading tbats-1.1.1-py3-none-any.whl (43 kB)
#      ---------------------------------------- 43.8/43.8 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.9.0 in d:\py_ana\lib\site-packages (from pycaret) (5.9.0)
# Collecting yellowbrick>=1.4
#   Using cached yellowbrick-1.5-py3-none-any.whl (282 kB)
# Requirement already satisfied: plotly>=5.0.0 in d:\py_ana\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: scikit-learn>=1.0 in d:\py_ana\lib\site-packages (from pycaret) (1.0.2)
# Collecting kaleido>=0.2.1
#   Downloading kaleido-0.2.1-py2.py3-none-win_amd64.whl (65.9 MB)
#      ---------------------------------------- 65.9/65.9 MB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: numba~=0.55.0 in d:\py_ana\lib\site-packages (from pycaret) (0.55.1)
# Collecting pyod>=0.9.8
#   Using cached pyod-1.0.6.tar.gz (141 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: joblib>=1.1.0 in d:\py_ana\lib\site-packages (from pycaret) (1.1.0)
# Requirement already satisfied: jinja2>=1.2 in d:\py_ana\lib\site-packages (from pycaret) (2.11.3)
# Collecting sktime~=0.13.2
#   Downloading sktime-0.13.4-py3-none-any.whl (7.0 MB)
#      ---------------------------------------- 7.0/7.0 MB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in d:\py_ana\lib\site-packages (from pycaret) (3.5.2)
# Requirement already satisfied: pandas<1.5.0,>=1.3.0 in d:\py_ana\lib\site-packages (from pycaret) (1.4.4)
# Requirement already satisfied: tqdm>=4.62.0 in d:\py_ana\lib\site-packages (from pycaret) (4.64.1)
# Collecting pmdarima!=1.8.1,<2.0.0,>=1.8.0
#   Downloading pmdarima-1.8.5-cp39-cp39-win_amd64.whl (601 kB)
#      -------------------------------------- 601.9/601.9 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.27.1 in d:\py_ana\lib\site-packages (from pycaret) (2.28.1)
# Collecting lightgbm>=3.0.0
#   Using cached lightgbm-3.3.3-py3-none-win_amd64.whl (1.0 MB)
# Collecting schemdraw>=0.14
#   Downloading schemdraw-0.15-py3-none-any.whl (106 kB)
#      -------------------------------------- 106.8/106.8 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=5.5.0 in d:\py_ana\lib\site-packages (from pycaret) (7.31.1)
# Requirement already satisfied: statsmodels>=0.12.1 in d:\py_ana\lib\site-packages (from pycaret) (0.13.2)
# Collecting imbalanced-learn>=0.8.1
#   Downloading imbalanced_learn-0.9.1-py3-none-any.whl (199 kB)
#      -------------------------------------- 199.3/199.3 kB 1.7 MB/s eta 0:00:00
# Collecting category-encoders>=2.4.0
#   Downloading category_encoders-2.5.1.post0-py2.py3-none-any.whl (72 kB)
#      -------------------------------------- 72.4/72.4 kB 440.8 kB/s eta 0:00:00
# Collecting plotly-resampler>=0.7.2.2
#   Downloading plotly_resampler-0.8.3.tar.gz (45 kB)
#      -------------------------------------- 45.5/45.5 kB 749.9 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting scikit-plot>=0.3.7
#   Using cached scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Requirement already satisfied: patsy>=0.5.1 in d:\py_ana\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\py_ana\lib\site-packages (from imbalanced-learn>=0.8.1->pycaret) (2.2.0)
# Collecting scikit-learn>=1.0
#   Downloading scikit_learn-1.2.0rc1-cp39-cp39-win_amd64.whl (17.0 MB)
#      ---------------------------------------- 17.0/17.0 MB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in d:\py_ana\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.8.0)
# Requirement already satisfied: matplotlib-inline in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: traitlets>=4.2 in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: decorator in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: pygments in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (2.11.2)
# Requirement already satisfied: pickleshare in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.20)
# Requirement already satisfied: backcall in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (63.4.1)
# Requirement already satisfied: colorama in d:\py_ana\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.5)
# Requirement already satisfied: ipykernel>=4.5.1 in d:\py_ana\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (6.15.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in d:\py_ana\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (1.0.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in d:\py_ana\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in d:\py_ana\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in d:\py_ana\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (5.5.0)
# Requirement already satisfied: wheel in d:\py_ana\lib\site-packages (from lightgbm>=3.0.0->pycaret) (0.37.1)
# Requirement already satisfied: pillow>=6.2.0 in d:\py_ana\lib\site-packages (from matplotlib>=3.3.0->pycaret) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\py_ana\lib\site-packages (from matplotlib>=3.3.0->pycaret) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\py_ana\lib\site-packages (from matplotlib>=3.3.0->pycaret) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\py_ana\lib\site-packages (from matplotlib>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in d:\py_ana\lib\site-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\py_ana\lib\site-packages (from matplotlib>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in d:\py_ana\lib\site-packages (from matplotlib>=3.3.0->pycaret) (21.3)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in d:\py_ana\lib\site-packages (from numba~=0.55.0->pycaret) (0.38.0)
# Requirement already satisfied: pytz>=2020.1 in d:\py_ana\lib\site-packages (from pandas<1.5.0,>=1.3.0->pycaret) (2022.1)
# Requirement already satisfied: tenacity>=6.2.0 in d:\py_ana\lib\site-packages (from plotly>=5.0.0->pycaret) (8.0.1)
# Collecting trace-updater>=0.0.8
#   Downloading trace_updater-0.0.9-py3-none-any.whl (185 kB)
#      -------------------------------------- 185.1/185.1 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: Werkzeug<=2.1.2 in d:\py_ana\lib\site-packages (from plotly-resampler>=0.7.2.2->pycaret) (2.0.3)
# Collecting jupyter-dash>=0.4.2
#   Downloading jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Collecting Flask-Cors<4.0.0,>=3.0.10
#   Using cached Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Collecting orjson<4.0.0,>=3.8.0
#   Downloading orjson-3.8.3-cp39-none-win_amd64.whl (200 kB)
#      ------------------------------------ 200.2/200.2 kB 871.4 kB/s eta 0:00:00
# Collecting dash<3.0.0,>=2.2.0
#   Downloading dash-2.7.0-py3-none-any.whl (9.9 MB)
#      ---------------------------------------- 9.9/9.9 MB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in d:\py_ana\lib\site-packages (from pmdarima!=1.8.1,<2.0.0,>=1.8.0->pycaret) (0.29.32)
# Requirement already satisfied: urllib3 in d:\py_ana\lib\site-packages (from pmdarima!=1.8.1,<2.0.0,>=1.8.0->pycaret) (1.26.11)
# Requirement already satisfied: six in d:\py_ana\lib\site-packages (from pyod>=0.9.8->pycaret) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\py_ana\lib\site-packages (from requests>=2.27.1->pycaret) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\py_ana\lib\site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\py_ana\lib\site-packages (from requests>=2.27.1->pycaret) (3.3)
# Collecting joblib>=1.1.0
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ------------------------------------ 298.0/298.0 kB 558.7 kB/s eta 0:00:00
# Collecting deprecated>=1.2.13
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting scikit-learn>=1.0
#   Downloading scikit_learn-1.1.3-cp39-cp39-win_amd64.whl (7.6 MB)
#      ---------------------------------------- 7.6/7.6 MB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: Flask>=1.0.4 in d:\py_ana\lib\site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (1.1.2)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in d:\py_ana\lib\site-packages (from deprecated>=1.2.13->sktime~=0.13.2->pycaret) (1.14.1)
# Requirement already satisfied: pyzmq>=17 in d:\py_ana\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (23.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\py_ana\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (7.3.4)
# Requirement already satisfied: tornado>=6.1 in d:\py_ana\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1)
# Requirement already satisfied: nest-asyncio in d:\py_ana\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.5)
# Requirement already satisfied: debugpy>=1.0 in d:\py_ana\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\py_ana\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Collecting retrying
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting ansi2html
#   Downloading ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: jupyter_core in d:\py_ana\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (4.11.1)
# Requirement already satisfied: jsonschema>=2.6 in d:\py_ana\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (4.16.0)
# Requirement already satisfied: fastjsonschema in d:\py_ana\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (2.16.2)
# Requirement already satisfied: wcwidth in d:\py_ana\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in d:\py_ana\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.12)
# Requirement already satisfied: itsdangerous>=0.24 in d:\py_ana\lib\site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (2.0.1)
# Requirement already satisfied: click>=5.1 in d:\py_ana\lib\site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (8.0.4)
# Requirement already satisfied: attrs>=17.4.0 in d:\py_ana\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\py_ana\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (0.18.0)
# Requirement already satisfied: entrypoints in d:\py_ana\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.4)
# Requirement already satisfied: pywin32>=1.0 in d:\py_ana\lib\site-packages (from jupyter_core->nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (302)
# Requirement already satisfied: nbconvert>=5 in d:\py_ana\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in d:\py_ana\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: prometheus-client in d:\py_ana\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.14.1)
# Requirement already satisfied: terminado>=0.8.3 in d:\py_ana\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.13.1)
# Requirement already satisfied: argon2-cffi in d:\py_ana\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.3.0)
# Requirement already satisfied: testpath in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.6.0)
# Requirement already satisfied: defusedxml in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.5.0)
# Requirement already satisfied: bleach in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.1.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.13)
# Requirement already satisfied: jupyterlab-pygments in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in d:\py_ana\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.8.4)
# Requirement already satisfied: pywinpty>=1.1.0 in d:\py_ana\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in d:\py_ana\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in d:\py_ana\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in d:\py_ana\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.3.1)
# Requirement already satisfied: webencodings in d:\py_ana\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: pycparser in d:\py_ana\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.21)
# Building wheels for collected packages: plotly-resampler, pyod
#   Building wheel for plotly-resampler (pyproject.toml): started
#   Building wheel for plotly-resampler (pyproject.toml): finished with status 'done'
#   Created wheel for plotly-resampler: filename=plotly_resampler-0.8.3-cp39-cp39-win_amd64.whl size=47315 sha256=cd873fefa811758eef31d35e821c287d91740d4418e639cc26337b9f37382f62
#   Stored in directory: c:\users\`\appdata\local\pip\cache\wheels\0d\1b\c0\1a3b8f6445c675f06caf524e3376a61e6e510149420eb385cc
#   Building wheel for pyod (setup.py): started
#   Building wheel for pyod (setup.py): finished with status 'done'
#   Created wheel for pyod: filename=pyod-1.0.6-py3-none-any.whl size=175082 sha256=3f93a8ec80f32325828455505169c3e034d12f076430a000b6f0e66d4f18b646
#   Stored in directory: c:\users\`\appdata\local\pip\cache\wheels\ac\4b\13\f396d3390477091d279889fb43e48096648535dd3cf07da023
# Successfully built plotly-resampler pyod
# Installing collected packages: trace-updater, kaleido, dash-table, dash-html-components, dash-core-components, scipy, schemdraw, retrying, orjson, joblib, importlib-metadata, deprecated, ansi2html, scikit-learn, yellowbrick, scikit-plot, lightgbm, imbalanced-learn, Flask-Cors, dash, sktime, pyod, pmdarima, jupyter-dash, category-encoders, tbats, plotly-resampler, pycaret
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.9.1
#     Uninstalling scipy-1.9.1:
#       Successfully uninstalled scipy-1.9.1
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.11.3
#     Uninstalling importlib-metadata-4.11.3:
#       Successfully uninstalled importlib-metadata-4.11.3
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
#   Attempting uninstall: pmdarima
#     Found existing installation: pmdarima 2.0.2
#     Uninstalling pmdarima-2.0.2:
#       Successfully uninstalled pmdarima-2.0.2
# Successfully installed Flask-Cors-3.0.10 ansi2html-1.8.0 category-encoders-2.5.1.post0 dash-2.7.0 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 deprecated-1.2.13 imbalanced-learn-0.9.1 importlib-metadata-5.1.0 joblib-1.2.0 jupyter-dash-0.4.2 kaleido-0.2.1 lightgbm-3.3.3 orjson-3.8.3 plotly-resampler-0.8.3 pmdarima-1.8.5 pycaret-3.0.0rc4 pyod-1.0.6 retrying-1.3.4 schemdraw-0.15 scikit-learn-1.1.3 scikit-plot-0.3.7 scipy-1.8.1 sktime-0.13.4 tbats-1.1.1 trace-updater-0.0.9 yellowbrick-1.5
# Collecting tensorflow
#   Downloading tensorflow-2.11.0-cp39-cp39-win_amd64.whl (1.9 kB)
# Collecting tensorflow-intel==2.11.0
#   Downloading tensorflow_intel-2.11.0-cp39-cp39-win_amd64.whl (266.3 MB)
#      ---------------------------------------- 266.3/266.3 MB ? eta 0:00:00
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: h5py>=2.9.0 in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.7.0)
# Collecting tensorboard<2.12,>=2.11
#   Downloading tensorboard-2.11.0-py3-none-any.whl (6.0 MB)
#      ---------------------------------------- 6.0/6.0 MB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (63.4.1)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting libclang>=13.0.0
#   Using cached libclang-14.0.6-py2.py3-none-win_amd64.whl (14.2 MB)
# Requirement already satisfied: absl-py>=1.0.0 in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.1.1)
# Requirement already satisfied: six>=1.12.0 in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.28.0-cp39-cp39-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 2.1 MB/s eta 0:00:00
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-22.12.6-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.14.1)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting tensorflow-estimator<2.12,>=2.11.0
#   Downloading tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
#      -------------------------------------- 439.2/439.2 kB 2.3 MB/s eta 0:00:00
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.51.1-cp39-cp39-win_amd64.whl (3.7 MB)
#      ---------------------------------------- 3.7/3.7 MB 1.7 MB/s eta 0:00:00
# Collecting keras<2.12,>=2.11.0
#   Downloading keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.21.5)
# Requirement already satisfied: packaging in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (21.3)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.6-cp39-cp39-win_amd64.whl (895 kB)
#      -------------------------------------- 895.9/895.9 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\py_ana\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.37.1)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\py_ana\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.28.1)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.15.0-py2.py3-none-any.whl (177 kB)
#      -------------------------------------- 177.0/177.0 kB 1.1 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ------------------------------------ 781.3/781.3 kB 580.6 kB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=1.0.1 in d:\py_ana\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.3)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in d:\py_ana\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\py_ana\lib\site-packages (from packaging->tensorflow-intel==2.11.0->tensorflow) (3.0.9)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\py_ana\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\py_ana\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: idna<4,>=2.5 in d:\py_ana\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\py_ana\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\py_ana\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\py_ana\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.11)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\py_ana\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      -------------------------------------- 151.7/151.7 kB 1.3 MB/s eta 0:00:00
# Installing collected packages: tensorboard-plugin-wit, libclang, flatbuffers, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, protobuf, opt-einsum, oauthlib, keras, grpcio, google-pasta, gast, astunparse, requests-oauthlib, google-auth, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
# Successfully installed astunparse-1.6.3 flatbuffers-22.12.6 gast-0.4.0 google-auth-2.15.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.51.1 keras-2.11.0 libclang-14.0.6 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-3.19.6 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.11.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.11.0 tensorflow-estimator-2.11.0 tensorflow-intel-2.11.0 tensorflow-io-gcs-filesystem-0.28.0
# WARNING: Error parsing requirements for pmdarima: [Errno 2] No such file or directory: 'd:\\py_ana\\lib\\site-packages\\pmdarima-2.0.2.dist-info\\METADATA'
#   WARNING: The scripts pyrsa-decrypt.exe, pyrsa-encrypt.exe, pyrsa-keygen.exe, pyrsa-priv2pub.exe, pyrsa-sign.exe and pyrsa-verify.exe are installed in 'C:\Users\`\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script google-oauthlib-tool.exe is installed in 'C:\Users\`\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tensorboard.exe is installed in 'C:\Users\`\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts estimator_ckpt_converter.exe, import_pb_to_tensorboard.exe, saved_model_cli.exe, tensorboard.exe, tf_upgrade_v2.exe, tflite_convert.exe, toco.exe and toco_from_protos.exe are installed in 'C:\Users\`\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Requirement already satisfied: tensorflow in c:\users\`\appdata\roaming\python\python39\site-packages (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.14.1)
# Requirement already satisfied: numpy>=1.20 in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.21.5)
# Requirement already satisfied: termcolor>=1.1.0 in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.1.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (22.12.6)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: six>=1.12.0 in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: setuptools in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (63.4.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (14.0.6)
# Requirement already satisfied: packaging in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (21.3)
# Requirement already satisfied: h5py>=2.9.0 in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.7.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.28.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.51.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\py_ana\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.15.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in d:\py_ana\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\py_ana\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.3)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\py_ana\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.28.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\py_ana\lib\site-packages (from packaging->tensorflow-intel==2.11.0->tensorflow) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\py_ana\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\`\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\py_ana\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\`\appdata\roaming\python\python39\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\py_ana\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\py_ana\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\py_ana\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in d:\py_ana\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\py_ana\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\`\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)
# Requirement already satisfied: tensorflow in c:\users\`\appdata\roaming\python\python39\site-packages (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: six>=1.12.0 in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.1.1)
# Requirement already satisfied: packaging in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (21.3)
# Requirement already satisfied: setuptools in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (63.4.1)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (22.12.6)
# Requirement already satisfied: absl-py>=1.0.0 in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.14.1)
# Requirement already satisfied: numpy>=1.20 in d:\py_ana\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.21.5)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (14.0.6)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.51.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.28.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\py_ana\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in d:\py_ana\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.15.0)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\py_ana\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\`\appdata\roaming\python\python39\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\py_ana\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\py_ana\lib\site-packages (from packaging->tensorflow-intel==2.11.0->tensorflow) (3.0.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\`\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\py_ana\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\py_ana\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\`\appdata\roaming\python\python39\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\py_ana\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\py_ana\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in d:\py_ana\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\py_ana\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.11)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\py_ana\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\`\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)

# %%
# !pip install pydot
# !pip install textblob
# !pip install wordcloud
# !pip install pillow
# Out:
# Collecting pydot
#   Using cached pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: pyparsing>=2.1.4 in d:\py_ana\lib\site-packages (from pydot) (3.0.9)
# Installing collected packages: pydot
# Successfully installed pydot-1.4.2
# Collecting textblob
#   Using cached textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# Requirement already satisfied: nltk>=3.1 in d:\py_ana\lib\site-packages (from textblob) (3.7)
# Requirement already satisfied: click in d:\py_ana\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in d:\py_ana\lib\site-packages (from nltk>=3.1->textblob) (2022.7.9)
# Requirement already satisfied: joblib in d:\py_ana\lib\site-packages (from nltk>=3.1->textblob) (1.2.0)
# Requirement already satisfied: tqdm in d:\py_ana\lib\site-packages (from nltk>=3.1->textblob) (4.64.1)
# Requirement already satisfied: colorama in d:\py_ana\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.5)
# Installing collected packages: textblob
# Successfully installed textblob-0.17.1
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp39-cp39-win_amd64.whl (153 kB)
#      ------------------------------------ 153.1/153.1 kB 539.0 kB/s eta 0:00:00
# Requirement already satisfied: pillow in d:\py_ana\lib\site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: matplotlib in d:\py_ana\lib\site-packages (from wordcloud) (3.5.2)
# Requirement already satisfied: numpy>=1.6.1 in d:\py_ana\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: cycler>=0.10 in d:\py_ana\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in d:\py_ana\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in d:\py_ana\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\py_ana\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\py_ana\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\py_ana\lib\site-packages (from matplotlib->wordcloud) (1.4.2)
# Requirement already satisfied: six>=1.5 in d:\py_ana\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2
# Requirement already satisfied: pillow in d:\py_ana\lib\site-packages (9.2.0)

# %%
# !pip install OpenCV-Python
# Out:
# Collecting OpenCV-Python
#   Downloading opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
#      ---------------------------------------- 35.6/35.6 MB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in d:\py_ana\lib\site-packages (from OpenCV-Python) (1.21.5)
# Installing collected packages: OpenCV-Python
# Successfully installed OpenCV-Python-4.6.0.66

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in d:\py_ana\lib\site-packages (1.16.0)
# Requirement already satisfied: watchdog in d:\py_ana\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: cachetools>=4.0 in d:\py_ana\lib\site-packages (from streamlit) (5.2.0)
# Requirement already satisfied: packaging>=14.1 in d:\py_ana\lib\site-packages (from streamlit) (21.3)
# Requirement already satisfied: requests>=2.4 in d:\py_ana\lib\site-packages (from streamlit) (2.28.1)
# Requirement already satisfied: pyarrow>=4.0 in d:\py_ana\lib\site-packages (from streamlit) (10.0.1)
# Requirement already satisfied: gitpython!=3.1.19 in d:\py_ana\lib\site-packages (from streamlit) (3.1.29)
# Requirement already satisfied: blinker>=1.0.0 in d:\py_ana\lib\site-packages (from streamlit) (1.5)
# Requirement already satisfied: python-dateutil in d:\py_ana\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: pympler>=0.9 in d:\py_ana\lib\site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: altair>=3.2.0 in d:\py_ana\lib\site-packages (from streamlit) (4.2.0)
# Requirement already satisfied: tornado>=5.0 in d:\py_ana\lib\site-packages (from streamlit) (6.1)
# Requirement already satisfied: importlib-metadata>=1.4 in d:\py_ana\lib\site-packages (from streamlit) (5.1.0)
# Requirement already satisfied: protobuf<4,>=3.12 in c:\users\`\appdata\roaming\python\python39\site-packages (from streamlit) (3.19.6)
# Requirement already satisfied: pandas>=0.21.0 in d:\py_ana\lib\site-packages (from streamlit) (1.4.4)
# Requirement already satisfied: tzlocal>=1.1 in d:\py_ana\lib\site-packages (from streamlit) (4.2)
# Requirement already satisfied: click>=7.0 in d:\py_ana\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: numpy in d:\py_ana\lib\site-packages (from streamlit) (1.21.5)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in d:\py_ana\lib\site-packages (from streamlit) (4.3.0)
# Requirement already satisfied: rich>=10.11.0 in d:\py_ana\lib\site-packages (from streamlit) (12.6.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\py_ana\lib\site-packages (from streamlit) (9.2.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in d:\py_ana\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: validators>=0.2 in d:\py_ana\lib\site-packages (from streamlit) (0.20.0)
# Requirement already satisfied: toml in d:\py_ana\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: semver in d:\py_ana\lib\site-packages (from streamlit) (2.13.0)
# Requirement already satisfied: jinja2 in d:\py_ana\lib\site-packages (from altair>=3.2.0->streamlit) (2.11.3)
# Requirement already satisfied: jsonschema>=3.0 in d:\py_ana\lib\site-packages (from altair>=3.2.0->streamlit) (4.16.0)
# Requirement already satisfied: entrypoints in d:\py_ana\lib\site-packages (from altair>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: toolz in d:\py_ana\lib\site-packages (from altair>=3.2.0->streamlit) (0.11.2)
# Requirement already satisfied: colorama in d:\py_ana\lib\site-packages (from click>=7.0->streamlit) (0.4.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\py_ana\lib\site-packages (from gitpython!=3.1.19->streamlit) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in d:\py_ana\lib\site-packages (from importlib-metadata>=1.4->streamlit) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\py_ana\lib\site-packages (from packaging>=14.1->streamlit) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in d:\py_ana\lib\site-packages (from pandas>=0.21.0->streamlit) (2022.1)
# Requirement already satisfied: six>=1.5 in d:\py_ana\lib\site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\py_ana\lib\site-packages (from requests>=2.4->streamlit) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\py_ana\lib\site-packages (from requests>=2.4->streamlit) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\py_ana\lib\site-packages (from requests>=2.4->streamlit) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in d:\py_ana\lib\site-packages (from requests>=2.4->streamlit) (3.3)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in d:\py_ana\lib\site-packages (from rich>=10.11.0->streamlit) (2.11.2)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in d:\py_ana\lib\site-packages (from rich>=10.11.0->streamlit) (0.9.1)
# Requirement already satisfied: pytz-deprecation-shim in d:\py_ana\lib\site-packages (from tzlocal>=1.1->streamlit) (0.1.0.post0)
# Requirement already satisfied: tzdata in d:\py_ana\lib\site-packages (from tzlocal>=1.1->streamlit) (2022.7)
# Requirement already satisfied: decorator>=3.4.0 in d:\py_ana\lib\site-packages (from validators>=0.2->streamlit) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in d:\py_ana\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\py_ana\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (2.0.1)
# Requirement already satisfied: attrs>=17.4.0 in d:\py_ana\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\py_ana\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.18.0)
# WARNING: Ignoring invalid distribution -treamlit (d:\py_ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (d:\py_ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (d:\py_ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (d:\py_ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (d:\py_ana\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (d:\py_ana\lib\site-packages)

# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.2-cp39-cp39-win_amd64.whl (572 kB)
#      ------------------------------------ 572.0/572.0 kB 799.1 kB/s eta 0:00:00
# Requirement already satisfied: urllib3 in d:\py_ana\lib\site-packages (from pmdarima) (1.26.11)
# Requirement already satisfied: statsmodels>=0.13.2 in d:\py_ana\lib\site-packages (from pmdarima) (0.13.2)
# Requirement already satisfied: scikit-learn>=0.22 in d:\py_ana\lib\site-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in d:\py_ana\lib\site-packages (from pmdarima) (1.1.0)
# Requirement already satisfied: scipy>=1.3.2 in d:\py_ana\lib\site-packages (from pmdarima) (1.9.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in d:\py_ana\lib\site-packages (from pmdarima) (0.29.32)
# Requirement already satisfied: pandas>=0.19 in d:\py_ana\lib\site-packages (from pmdarima) (1.4.4)
# Requirement already satisfied: numpy>=1.21.2 in d:\py_ana\lib\site-packages (from pmdarima) (1.21.5)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in d:\py_ana\lib\site-packages (from pmdarima) (63.4.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\py_ana\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\py_ana\lib\site-packages (from pandas>=0.19->pmdarima) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\py_ana\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in d:\py_ana\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in d:\py_ana\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\py_ana\lib\site-packages (from packaging>=21.3->statsmodels>=0.13.2->pmdarima) (3.0.9)
# Requirement already satisfied: six in d:\py_ana\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.0.2

# %%
# !pip install altair
# Out:
# Requirement already satisfied: altair in d:\py_ana\lib\site-packages (4.2.0)
# Requirement already satisfied: entrypoints in d:\py_ana\lib\site-packages (from altair) (0.4)
# Requirement already satisfied: pandas>=0.18 in d:\py_ana\lib\site-packages (from altair) (1.4.4)
# Requirement already satisfied: numpy in d:\py_ana\lib\site-packages (from altair) (1.21.5)
# Requirement already satisfied: jsonschema>=3.0 in d:\py_ana\lib\site-packages (from altair) (4.16.0)
# Requirement already satisfied: toolz in d:\py_ana\lib\site-packages (from altair) (0.11.2)
# Requirement already satisfied: jinja2 in d:\py_ana\lib\site-packages (from altair) (2.11.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\py_ana\lib\site-packages (from jsonschema>=3.0->altair) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in d:\py_ana\lib\site-packages (from jsonschema>=3.0->altair) (21.4.0)
# Requirement already satisfied: pytz>=2020.1 in d:\py_ana\lib\site-packages (from pandas>=0.18->altair) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\py_ana\lib\site-packages (from pandas>=0.18->altair) (2.8.2)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\py_ana\lib\site-packages (from jinja2->altair) (2.0.1)
# Requirement already satisfied: six>=1.5 in d:\py_ana\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.18->altair) (1.16.0)

# %%
# !pip install pickle5
# Out:
# Collecting pickle5
#   Downloading pickle5-0.0.11.tar.gz (132 kB)
#      ------------------------------------ 132.1/132.1 kB 199.8 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: pickle5
#   Building wheel for pickle5 (setup.py): started
#   Building wheel for pickle5 (setup.py): finished with status 'error'
#   Running setup.py clean for pickle5
# Failed to build pickle5
# Installing collected packages: pickle5
#   Running setup.py install for pickle5: started
#   Running setup.py install for pickle5: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [17 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-39
#   creating build\lib.win-amd64-cpython-39\pickle5
#   copying pickle5\pickle.py -> build\lib.win-amd64-cpython-39\pickle5
#   copying pickle5\pickletools.py -> build\lib.win-amd64-cpython-39\pickle5
#   copying pickle5\__init__.py -> build\lib.win-amd64-cpython-39\pickle5
#   creating build\lib.win-amd64-cpython-39\pickle5\test
#   copying pickle5\test\pickletester.py -> build\lib.win-amd64-cpython-39\pickle5\test
#   copying pickle5\test\test_pickle.py -> build\lib.win-amd64-cpython-39\pickle5\test
#   copying pickle5\test\test_picklebuffer.py -> build\lib.win-amd64-cpython-39\pickle5\test
#   copying pickle5\test\__init__.py -> build\lib.win-amd64-cpython-39\pickle5\test
#   running build_ext
#   building 'pickle5._pickle' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pickle5
#   error: subprocess-exited-with-error
#
#   Running setup.py install for pickle5 did not run successfully.
#   exit code: 1
#
#   [19 lines of output]
#   running install
#   D:\PY_ANA\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     warnings.warn(
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-39
#   creating build\lib.win-amd64-cpython-39\pickle5
#   copying pickle5\pickle.py -> build\lib.win-amd64-cpython-39\pickle5
#   copying pickle5\pickletools.py -> build\lib.win-amd64-cpython-39\pickle5
#   copying pickle5\__init__.py -> build\lib.win-amd64-cpython-39\pickle5
#   creating build\lib.win-amd64-cpython-39\pickle5\test
#   copying pickle5\test\pickletester.py -> build\lib.win-amd64-cpython-39\pickle5\test
#   copying pickle5\test\test_pickle.py -> build\lib.win-amd64-cpython-39\pickle5\test
#   copying pickle5\test\test_picklebuffer.py -> build\lib.win-amd64-cpython-39\pickle5\test
#   copying pickle5\test\__init__.py -> build\lib.win-amd64-cpython-39\pickle5\test
#   running build_ext
#   building 'pickle5._pickle' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# pickle5
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
# !pip install python-pipeline
# Out:
# Collecting python-pipeline
#   Downloading python-pipeline-1.0.tar.gz (1.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: python-pipeline
#   Building wheel for python-pipeline (setup.py): started
#   Building wheel for python-pipeline (setup.py): finished with status 'done'
#   Created wheel for python-pipeline: filename=python_pipeline-1.0-py3-none-any.whl size=2378 sha256=c06a9b7673abb38c90b5b16c445c788fe4153fb6532224c070a5161712048d5f
#   Stored in directory: c:\users\`\appdata\local\pip\cache\wheels\42\79\18\a794f7226a4f7bc77026f86e6692d3eb0f4399bb921a3a98c5
# Successfully built python-pipeline
# Installing collected packages: python-pipeline
# Successfully installed python-pipeline-1.0
